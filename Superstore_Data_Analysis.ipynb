# %%
import os
print(os.listdir())
# Out:
# ['.anaconda', '.arduinoIDE', '.conda', '.continuum', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.ms-ad', '.qucs', '.spyder-py3', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'array using np.py', 'concatenate string.py', 'Contacts', 'Cookies', 'Documents', 'Downloads', 'Favorites', 'IntelGraphicsProfiles', 'Jedi', 'largest.py', 'Links', 'Local Settings', 'MATT.py', 'miktex-console.lock', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{ea307dc9-5a79-11f0-ade3-99e4081eb9bd}.TM.blf', 'NTUSER.DAT{ea307dc9-5a79-11f0-ade3-99e4081eb9bd}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{ea307dc9-5a79-11f0-ade3-99e4081eb9bd}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'simple calculator.py', 'Start Menu', 'Templates', 'Untitled.ipynb', 'untitled0.py', 'Untitled1.ipynb', 'untitled1.py', 'Untitled2.ipynb', 'untitled2.py', 'untitled3.py', 'untitled4.py', 'untitled5.py', 'Videos', 'WPS Cloud Files', 'WPSDrive']

# %%
import os

os.chdir("Downloads")

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Karun\Downloads
# ['+2- Model Exam Live- English.pdf', '.ipynb_checkpoints', '11 P4 New (1).pdf', '11 P4 New.pdf', 'AdmitCard-230310554259 (1).pdf', 'AdmitCard-230310554259.pdf', 'Adobe Scan 16-Jan-2025 (1).pdf', 'allotmentmemoknr.pdf', 'Anaconda3-2025.12-2-Windows-x86_64.exe', 'archive (1).zip', 'archive (2).zip', 'archive.zip', 'B.DesS1-S7APRIL2026(2019SCH)APPROVED.pdf', 'Boundary conditions.pdf', 'CAM MODULE 2 (1).pptx', 'CAP26PG135430.pdf', 'Capacitance.pdf', 'carbon (1).png', 'carbon (2).png', 'carbon (3).png', 'carbon (4).png', 'carbon.png', 'ChatGPT Image Apr 5, 2026, 10_54_16 PM.png', 'ChatGPT Image Apr 5, 2026, 10_54_32 PM.png', 'ChatGPT Image Apr 5, 2026, 10_56_10 PM.png', 'ckt.png', 'cktfinal (1).pdf', 'cktfinal (2).pdf', 'clampers circuits RHS (1).pdf', 'clampers circuits RHS.pdf', 'clampers LHS.pdf', 'cleaned_dataset.csv', 'code-snippet (1).png', 'Copy of Copy of Copy of ECOSYSTEM.pdf', 'Copy of Organisms And Population .pdf', 'd8048a22-3544-4dd7-931a-c0d7ad71c765.zip', 'DEC 2025-QP.pdf', 'desktop.ini', 'Differential Equation Feb. 23.pdf', 'Djamm.pdf', 'do.aux', 'do.log', 'do.pdf', 'do.synctex.gz', 'do.tex', 'DOC-20230205-WA0010.pdf', 'DOC-20260608-WA0001.xlsx', 'doc.aux', 'doc.log', 'doc.pdf', 'doc.synctex.gz', 'doc.tex', 'document.tex', 'ECT 304 - VLSI Circuit Design Module 1 original (1).pptx', 'ECT 304 - VLSI Circuit Design Module 1 original.pptx', 'ECT 304 - VLSI Circuit Design Module 4.pptx', 'ECT304 VLSI CIRCUIT DESIGN MAY 2024 (2).pdf', 'ECT304 VLSI CIRCUIT DESIGN, APRIL 2025 (2).pdf', 'ECT304 VLSI CIRCUIT DESIGN, JUNE 2022 (1) (2).pdf', 'ECT304 VLSI CIRCUIT DESIGN, JUNE 2023 (2).pdf', 'ECT304-QP-1 (2).pdf', 'ECT304-QP-2 (2).pdf', 'ECT304-VLSI-MODULE 2.pdf', 'ECT306 INFORMATION THEORY AND CODING, JUNE 2022.pdf', 'ECT306-QP-1.pdf', 'ECT306-QP-2.pdf', 'ECT306-QP-4 (1).pdf', 'ECT306-QP-4 (2).pdf', 'ECT306-QP-4.pdf', 'ECT306-QP.pdf', 'ECT306_3_Mark_Questions.pdf', 'ECT362-B (2).pdf', 'ECT362-QP (1) (4).pdf', 'ECT362-QP (3) (2).pdf', 'ECT362-QP (5).pdf', 'ECT362-QP (6).pdf', 'Electronics Comprehensive Qbank April 2018 - Kerala Notes.pdf', 'EMT Module 1 (1).pdf', 'EMT Module 1.pdf', 'Emtmod4.pdf', 'EMTModule4 (1).pdf', 'EMTModule4.pdf', 'Expt3- Clipping circuits LHS of record .pdf', 'fee2026.pdf', 'flow.pdf', 'Gantt_Semi_Automatic_Pepper_Plucking_Device_with_Arrows.xlsx', 'Hsslive-practical-qn-2020-chemistry-signed.pdf', 'Hsslive-xii-biology-term-2-dec-2022-key-dr-sunil-kumar.pdf', 'Hsslive-xii-chemistry-term-2-dec-2022-key-anil-kumar.pdf', 'Hsslive-xii-zoology-ch-1-human-reproduction-navas.pdf', 'HSSRptr- Zool-Sample-PRACTICAL2021.PDF.pdf', 'hssrptr_+2 English 100 Imp Questions  Public Examination 2023.pdf', 'HSSRptr_+2 Previous years question paper chapterwise.pdf', 'hssrptr_2-SMILE 2023-PLUS TWO CHEMISTRY.pdf', 'hssrptr_3-SMILE 2023-PLUS TWO-BOTANY-FNL.pdf', 'hssrptr_Answers +2 Hundred Questions by FHET Mlpm.pdf', 'hssrptr_Botany Practical Notes-2023 hssrporter.pdf', 'hssrptr_Botany Practical Q & Key-2023.pdf', 'hssrptr_Final Smile +2 Physics 2023 by Kannur (1).pdf', 'hssrptr_Final Smile +2 Physics 2023 by Kannur.pdf', 'hssrptr_PLUS TWO ENGLISH NOTES.pdf', 'hssrptr_Plus Two Phy Questions Bank 2023 hssreporter (1).pdf', 'hssrptr_Plus Two Phy Questions Bank 2023 hssreporter.pdf', 'hssrptr_Plus Two Physics Chapter wise Weightage.pdf', 'hssrptr_Plus Two Physics Full Notes for 2023-Seema Tr.pdf', 'hssrptr_Practical Theory points 2023-hssrporter (1).pdf', 'hssrptr_Practical Theory points 2023-hssrporter (2).pdf', 'hssrptr_Practical Theory points 2023-hssrporter (3).pdf', 'hssrptr_XII Prev Pic based qns.2012-22 all chapters.pdf', 'hssrptr_ZOOLOGY  PRACTICAL 2023-hssreporter.pdf', 'HSSRptr_Zoology Practical 2022.pdf', 'hssrptr_Zoology Practical ppt 2022.pdf', 'hssrptr• Revaluation Result With Marks Change.pdf', 'hssrptr•+1 Improvement Revaluation Result-22 (1).pdf', 'hssrptr•+1 Improvement Revaluation Result-22 (2).pdf', 'hssrptr•+1 Improvement Revaluation Result-22.pdf', 'hssrptr•Botany Practical Exam Guidelines 2022-2023.pdf', 'Huma ...

# %%
import pandas as pd

df = pd.read_csv("Sample - Superstore.csv",encoding="latin1")

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.groupby("Category")["Sales"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Category'>

# %%
import matplotlib.pyplot as plt

df.groupby("Category")["Sales"].sum().plot(kind="bar")
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
df.groupby("Category")["Sales"].sum().plot(kind="pie",autopct="%1.1f%%")
plt.title("Sales Distribution by Category")
plt.ylabel("")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

df.groupby("Category")["Profit"].sum().plot(kind="bar")
plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit")
plt.show()

# %%
import matplotlib.pyplot as plt

df.groupby("Region")["Sales"].sum().plot(kind="bar")
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# %%
df.groupby("Segment")["Sales"].sum().plot(kind="bar")
plt.title("Sales by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Total Sales")
plt.show()
